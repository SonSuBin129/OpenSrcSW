# %%
x=int(input("계산할 x의 값을 입력하시오: "))
y=3*x*x+5*x+3
print("계산한 결과: "+str(y))
# Out:
# 계산할 x의 값을 입력하시오: 5
# 계산한 결과: 103

# %%
r=int(input("반지름을 입력하시오: "))
pi=3.14
L=2*pi*r
S=pi*r*r
print("원의 둘레(소수점 두번째 자리까지) : {0:.2f}, 원의 넓이(소수점 두번째 자리까지) : {1:.2f}".format(L,S))
# Out:
# 반지름을 입력하시오: 10
# 원의 둘레(소수점 두번째 자리까지) : 62.80, 원의 넓이(소수점 두번째 자리까지) : 314.00
